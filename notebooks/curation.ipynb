# %% [markdown]
# # Creating record set curation file
#
# - Fields in recordsets are annotated as a manual effort done by multiple people.
# - Curation was collected in a Google spreadsheet table.
# - The table has columns to make it easier for the curators to annotated also, also provides extra annotation for croissant ingestion
#
# ## Columns
#
# - `dataset_name` - name of the dataset for curators.
# - `field_id` - identifier of the field for croissant.
# - `column_name` - just the label of the field for curators.
# - `column_description` - Curators annotate fields with description
# - `foreign_key` - curators add `field_id` of the foreign field
# - `bioregistry_prefix` - if data in a column comes from a database in bioregisty, annotate
# - `example` - helps curatos
#
# ## Process
#
# 1. Fetch curation table from Google
# 2. Composing description
# 3. Iterating over column and building output
# 4. Save curation as json.

# %%
import pandas as pd
import json

# Curation of all columns from all OpenTargets output datasets:
curation = 'https://docs.google.com/spreadsheets/d/132SKHMoaJePu4nTlBnQwfaz3dhfJiKmJUujfYkzXMdI/export?format=tsv&gid=179018892'

# Folder to save the resulting curation file:
asset_folder = '../src/ot_croissant/assets/'

# Reading table:
curation_table = (
    pd.read_csv(curation, sep='\t')
    .astype(
        {
            'column_description': pd.StringDtype(),
            'foreign_key': pd.StringDtype(),
        }
    )
)
curation_table.head()
# Out:
#         dataset_name                                field_id  column_name  \
# 0  disease_phenotype               disease_phenotype/disease      disease
# 1  disease_phenotype             disease_phenotype/phenotype    phenotype
# 2  disease_phenotype              disease_phenotype/evidence     evidence
# 3  disease_phenotype       disease_phenotype/evidence/aspect       aspect
# 4  disease_phenotype  disease_phenotype/evidence/bioCuration  bioCuration
#
#                                   column_description foreign_key  \
# 0                                 Disease identifier  disease/id
# 1               The phenotype linked to the disease.  disease/id
# 2  A container for all evidence-related attribute...        <NA>
# 3  The category of biological information being p...        <NA>
# 4  Indicates whether the evidence has been manual...        <NA>
#
#   bioregistry_prefix                                            Example
# 0                NaN                                      MONDO_0800026
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                  C
# 4                NaN  HPO:probinson[2021-09-23];HPO:probinson[2021-0...

# %%
# Collection of curated dataset:
curation_json = []

# Composing description:
def compose_description(row: pd.Series) -> str:
    """
    Composes the description of a column based on the bioregistry prefix and the column description.
    If the bioregistry prefix is not available, it returns the column description as is.

    Args:
        row (pd.Series): A row from the curation table.
    
    Returns:
        str: The composed description.
    """
    # If the bioregistry prefix is not available, return the column description as is:
    description = (
        row['column_description']
        if pd.isna(row['bioregistry_prefix'])
        else f"{row['column_description']} [bioregistry:{row['bioregistry_prefix'].lower()}]"
    )

    return description

# Iterating over the rows of the curation table:
for _, row in curation_table.iterrows():
    # If the column description is not available, skip the row:
    if pd.isna(row['column_description']):
        continue

    # Adding curation to the dictionary:
    data = {
        'id': row['field_id'],
        'description': compose_description(row)
    }

    # If the foreign key is available, add it to the dictionary:
    if not pd.isna(row['foreign_key']):
        data['foreign_key'] = row['foreign_key']

    # If the bioregistry prefix is available, add it to the dictionary:
    curation_json.append(data)

# Saving the curation to a JSON file:
with open(f'{asset_folder}/recordset.json', 'w') as f:
    json.dump(curation_json, f, indent=2)

# %%
# Columns with bioregistry prefix:
curation_table.loc[curation_table.bioregistry_prefix.notna()]
# Out:
#              dataset_name                                           field_id  \
# 14      disease_phenotype              disease_phenotype/evidence/references
# 20        mouse_phenotype                mouse_phenotype/biologicalModels/id
# 21        mouse_phenotype        mouse_phenotype/biologicalModels/literature
# 23        mouse_phenotype           mouse_phenotype/modelPhenotypeClasses/id
# 25        mouse_phenotype                   mouse_phenotype/modelPhenotypeId
# 29        mouse_phenotype             mouse_phenotype/targetInModelEnsemblId
# 30        mouse_phenotype                 mouse_phenotype/targetInModelMgiId
# 48               reactome                                        reactome/id
# 55             expression                                      expression/id
# 57             expression                        expression/tissues/efo_code
# 83                 target                                          target/id
# 102                target                                       target/go/id
# 106                target                              target/go/geneProduct
# 107                target                                    target/go/ecoId
# 110                target                   target/hallmarks/attributes/pmid
# 114                target              target/hallmarks/cancerHallmarks/pmid
# 131                target                 target/subcellularLocations/termSL
# 329                    go                                              go/id
# 331                    so                                              so/id
# 349             biosample                              biosample/biosampleId
# 391              evidence                                evidence/ancestryId
# 409              evidence              evidence/biomarkers/geneExpression/id
# 412              evidence  evidence/biomarkers/geneticVariation/functiona...
# 433              evidence                 evidence/diseaseCellLines/tissueId
# 438              evidence  evidence/diseaseModelAssociatedHumanPhenotypes/id
# 441              evidence  evidence/diseaseModelAssociatedModelPhenotypes/id
# 444              evidence                                    evidence/drugId
# 456              evidence    evidence/mutatedSamples/functionalConsequenceId
# 466              evidence                               evidence/pathways/id
# 496              evidence                    evidence/targetInModelEnsemblId
# 497              evidence                        evidence/targetInModelMgiId
# 505              evidence            evidence/variantFunctionalConsequenceId
# 541      pharmacogenomics    pharmacogenomics/variantFunctionalConsequenceId
# 548   target_essentiality                             target_essentiality/id
# 559   target_essentiality  target_essentiality/geneEssentiality/depMapEss...
# 596  interaction_evidence                       interaction_evidence/targetB
# 599  interaction_evidence  interaction_evidence/participantDetectionMetho...
# 608  interaction_evidence   interaction_evidence/interactionTypeMiIdentifier
# 609  interaction_evidence   interaction_evidence/expansionMethodMiIdentifier
# 628  interaction_evidence  interaction_evidence/participantDetectionMetho...
# 632  interaction_evidence                       interaction_evidence/targetA
# 633  interaction_evidence  interaction_evidence/interactionDetectionMetho...
# 650               variant                     variant/variantEffect/targetId
# 652               variant                    variant/mostSevereConsequenceId
# 654               variant  variant/transcriptConsequences/variantFunction...
# 656               variant   variant/transcriptConsequences/uniprotAccessions
# 663               variant            variant/transcriptConsequences/targetId
# 672               variant        variant/transcriptConsequences/transcriptId
# 683           interaction                                interaction/targetA
# 686           interaction                                interaction/targetB
# 700                 study                                       study/geneId
# 706                 study                                     study/pubmedId
# 736                 study                                  study/biosampleId
#
#                                 column_name  \
# 14                               references
# 20                                       id
# 21                               literature
# 23                                       id
# 25                         modelPhenotypeId
# 29                   targetInModelEnsemblId
# 30                       targetInModelMgiId
# 48                                       id
# 55                                       id
# 57                                 efo_code
# 83                                       id
# 102                                      id
# 106                             geneProduct
# 107                                   ecoId
# 110                                    pmid
# 114                                    pmid
# 131                                  termSL
# 329                                      id
# 331                                      id
# 349                             biosampleId
# 391                              ancestryId
# 409                                      id
# 412                 functionalConsequenceId
# 433                                tissueId
# 438                                      id
# 441                                      id
# 444                                  drugId
# 456                 functionalConsequenceId
# 466                                      id
# 496                  targetInModelEnsemblId
# 497                      targetInModelMgiId
# 505          variantFunctionalConsequenceId
# 541          variantFunctionalConsequenceId
# 548                                      id
# 559                                tissueId
# 596                                 targetB
# 599                            miIdentifier
# 608             interactionTypeMiIdentifier
# 609             expansionMethodMiIdentifier
# 628                            miIdentifier
# 632                                 targetA
# 633  interactionDetectionMethodMiIdentifier
# 650                                targetId
# 652                 mostSevereConsequenceId
# 654         variantFunctionalConsequenceIds
# 656                       uniprotAccessions
# 663                                targetId
# 672                            transcriptId
# 683                                 targetA
# 686                                 targetB
# 700                                  geneId
# 706                                pubmedId
# 736                             biosampleId
#
#                                     column_description  \
# 14    References or citations supporting the evidence.
# 20         Unique identifier for the biological model.
# 21              References related to the mouse model.
# 23          Unique identifier for the phenotype class.
# 25   Identifier for the specific phenotype observed...
# 29   Ensembl identifier for the target gene in the ...
# 30   MGI (Mouse Genome Informatics) identifier for ...
# 48          Unique identifier for the Reactome pathway
# 55   Ensembl human gene identifier for the expresse...
# 57   Ontology ID of the biosample the expression da...
# 83                    Unique identifier for the target
# 102                   GO identifier for the annotation
# 106     Gene product associated with the GO annotation
# 107  Evidence & Conclusion Ontology (ECO) identifie...
# 110  PubMed ID of the supporting literature for the...
# 114  PubMed ID of the supporting literature for the...
# 131  Subcellular location term identifier from Swis...
# 329                      Gene ontology term identifier
# 331                  Sequence ontology term identifier
# 349                Unique identifier for the biosample
# 391  Identifier of the ancestry in the HANCESTRO on...
# 409  Gene Ontology (GO) identifiers of regulation o...
# 412  Functional consequene identifier of the varian...
# 433  Anatomical identifier of the sampled organ/tissue
# 438                Human phenotype ontology identifier
# 441                Mouse phenotype ontology identifier
# 444                       Open Targets drug identifier
# 456  Functional consequene identifier of the pooled...
# 466                        Reactome pathway identifier
# 496                  Target Ensembl ID in animal model
# 497                      Target MGI ID in animal model
# 505  Sequence ontology (SO) identifier of the funct...
# 541  The sequence ontology identifier of the conseq...
# 548  Target identifier the essentiality was measure...
# 559  Identifier of the tissue from where the cells ...
# 596  Open Targets target identifier of the second m...
# 599  Molecular Interactions (MI) identifier for par...
# 608  Molecular Interactions (MI) identifier for the...
# 609  Molecular Interactions (MI) identifier for the...
# 628  Molecular Interactions (MI) identifier for par...
# 632  Open Targets target identifier of the second m...
# 633  Molecular Interactions (MI) identifier for the...
# 650  The target identifier on which the variant eff...
# 652  The sequence ontology identifier of the most s...
# 654  The sequence ontology identifier of the conseq...
# 656    List of Uniprot identifiers of the gene product
# 663    Open Target target identifier of the transcript
# 672                  The Ensembl transcript identifier
# 683  Open Targets target identifier of the first mo...
# 686  Open Targets target identifier of the second m...
# 700  Ensembl identifier of the gene representing a ...
# 706  PubMed identifier of the publication hat refer...
# 736  Biosample identifier that maps to the biosampl...
#
#                           foreign_key bioregistry_prefix             Example
# 14                               <NA>             pubmed     [PMID:14566559]
# 20                               <NA>                MGI         MGI:6140117
# 21                               <NA>             pubmed          [30949703]
# 23                               <NA>                 MP          MP:0005389
# 25                               <NA>                 MP          MP:0005343
# 29                               <NA>            ENSEMBL  ENSMUSG00000087651
# 30                               <NA>                MGI         MGI:1917034
# 48                               <NA>           reactome                 NaN
# 55                               <NA>            ENSEMBL     ENSG00000071243
# 57              biosample/biosampleId             UBERON                 NaN
# 83                               <NA>            ENSEMBL                 NaN
# 102                             go/id                 GO                 NaN
# 106                              <NA>            uniprot                 NaN
# 107                              <NA>                ECO                 NaN
# 110                              <NA>             pubmed                 NaN
# 114                              <NA>             pubmed                 NaN
# 131                              <NA>                 SL                 NaN
# 329                              <NA>                 go                 NaN
# 331                              <NA>                 so                 NaN
# 349                              <NA>             UBERON                 NaN
# 391                              <NA>          HANCESTRO                 NaN
# 409                              <NA>                 GO                 NaN
# 412                             so/id                 SO                 NaN
# 433             biosample/biosampleId             UBERON                 NaN
# 438                    disease_hpo/id                 HP                 NaN
# 441  mouse_phenotype/modelPhenotypeId                 MP                 NaN
# 444                  drug_molecule/id             CHEMBL                 NaN
# 456                             so/id                 SO                 NaN
# 466                       reactome/id           reactome                 NaN
# 496                              <NA>            ENSEMBL                 NaN
# 497                              <NA>                MGI                 NaN
# 505                             so/id                 SO                 NaN
# 541                             so/id                 SO                 NaN
# 548                         target/id            ENSEMBL                 NaN
# 559             biosample/biosampleId             UBERON                 NaN
# 596                         target/id            ENSEMBL                 NaN
# 599                              <NA>                 MI                 NaN
# 608                              <NA>                 MI                 NaN
# 609                              <NA>                 MI                 NaN
# 628                              <NA>                 MI                 NaN
# 632                         target/id            ENSEMBL                 NaN
# 633                              <NA>                 MI                 NaN
# 650                         target/id            ENSEMBL                 NaN
# 652                             so/id                 SO                 NaN
# 654                             so/id                 SO                 NaN
# 656                              <NA>            UNIPROT                 NaN
# 663                         target/id            ENSEMBL                 NaN
# 672                              <NA>            ENSEMBL                 NaN
# 683                         target/id            ENSEMBL                 NaN
# 686                         target/id            ENSEMBL                 NaN
# 700                         target/id            ENSEMBL                 NaN
# 706                   literature/pmid             PUBMED                 NaN
# 736             biosample/biosampleId             UBERON                 NaN

# %%
# Fields without description:
curation_table.loc[curation_table.column_description.isna()]
# Out:
#    dataset_name                                          field_id  \
# 67   expression            expression/tissues/protein/reliability
# 71   expression  expression/tissues/protein/cell_type/reliability
# 72   expression        expression/tissues/protein/cell_type/level
#
#     column_name column_description foreign_key bioregistry_prefix Example
# 67  reliability               <NA>        <NA>                NaN     NaN
# 71  reliability               <NA>        <NA>                NaN     NaN
# 72        level               <NA>        <NA>                NaN     NaN

# %% [markdown]
# # Adding tags to distributions

# %%
import pandas as pd
import json

# Curation of all columns from all OpenTargets output datasets:
curation = 'https://docs.google.com/spreadsheets/d/1JBu9HsRqwdGYMsYVoNAghmyEoU34S7fFnNIjHuzl0To/export?format=tsv'

# Folder to save the resulting curation file:
asset_folder = '../src/ot_croissant/assets/'

# Reading table:
curation_table = (
    pd.read_csv(curation, sep='\t')
    .rename(columns={'Dataset': 'id', 'Tag': 'tag'})
    .assign(
        tags = lambda df: df.tag.str.split('|')
    )
    [['id', 'tags']]
)

curation_table.head()
# Out:
#                                    id              tags
# 0    association_by_datasource_direct  [Target-Disease]
# 1  association_by_datasource_indirect  [Target-Disease]
# 2      association_by_datatype_direct  [Target-Disease]
# 3    association_by_datatype_indirect  [Target-Disease]
# 4     association_by_overall_indirect  [Target-Disease]

# %%
# Collection of curated dataset:
curation_json = []

for _, row in (
    pd.read_json(f'{asset_folder}/distribution.json', orient='records')
    .merge(curation_table, on='id', how='left')
).iterrows():
    curation_json.append(
        row.to_dict()
    )


# Saving the curation to a JSON file:
with open(f'{asset_folder}/distribution.json', 'w') as f:
    json.dump(curation_json, f, indent=2)

# %%
(
    pd.read_json(f'{asset_folder}/distribution.json', orient='records')
    .merge(curation_table, on='id', how='left')
    .to_json(f'{asset_folder}/distribution_v2.json', orient='table', indent=2, lines=False)
)

# %%
from pyspark.sql import SparkSession, functions as f, types as t


spark = SparkSession.builder.getOrCreate()
df = (
    spark.read.csv('/Users/dsuveges/33414548-GCST90010801-EFO_0010226.h.tsv.gz', sep='\t', header=True)
)


df.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/04/29 11:41:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +--------------+-----------+--------+--------+---------------+----------------+-------+-------------+-----------+-----------+--------------------------+-------+----------+------------------+-------------+------------+-------+----------+--------+--------+----+--------------+-----------------------+-----------+
# | hm_variant_id|    hm_rsid|hm_chrom|  hm_pos|hm_other_allele|hm_effect_allele|hm_beta|hm_odds_ratio|hm_ci_lower|hm_ci_upper|hm_effect_allele_frequency|hm_code|chromosome|base_pair_location|effect_allele|other_allele|p_value|odds_ratio|ci_lower|ci_upper|beta|standard_error|effect_allele_frequency| variant_id|
# +--------------+-----------+--------+--------+---------------+----------------+-------+-------------+-----------+-----------+--------------------------+-------+----------+------------------+-------------+------------+-------+----------+--------+--------+----+--------------+-----------------------+-----------+
# |1_99534456_G_T| rs10875231|       1|99534456|              G|               T|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99534456|            T|           G| 0.2697|        NA|      NA|      NA|  NA|            NA|                     NA| rs10875231|
# |1_99535271_C_T|  rs6678176|       1|99535271|              C|               T|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99535271|            T|           C| 0.2028|        NA|      NA|      NA|  NA|            NA|                     NA|  rs6678176|
# |1_99535287_T_C| rs78286437|       1|99535287|              T|               C|     NA|           NA|         NA|         NA|                        NA|     11|         1|          99535287|            T|           C| 0.1592|        NA|      NA|      NA|  NA|            NA|                     NA| rs78286437|
# |1_99535645_G_T| rs76909621|       1|99535645|              G|               T|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99535645|            T|           G|0.03791|        NA|      NA|      NA|  NA|            NA|                     NA| rs76909621|
# |1_99536934_C_T| rs78642210|       1|99536934|              C|               T|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99536934|            T|           C| 0.1561|        NA|      NA|      NA|  NA|            NA|                     NA| rs78642210|
# |1_99537157_C_T| rs77140576|       1|99537157|              C|               T|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99537157|            T|           C|0.03355|        NA|      NA|      NA|  NA|            NA|                     NA| rs77140576|
# |1_99537158_A_G|rs113470118|       1|99537158|              A|               G|     NA|           NA|         NA|         NA|                        NA|     11|         1|          99537158|            A|           G| 0.1419|        NA|      NA|      NA|  NA|            NA|                     NA|rs113470118|
# |1_99537326_T_G|  rs7545818|       1|99537326|              T|               G|     NA|           NA|         NA|         NA|                        NA|     11|         1|          99537326|            T|           G| 0.6851|        NA|      NA|      NA|  NA|            NA|                     NA|  rs7545818|
# |1_99537435_G_A| rs75635821|       1|99537435|              G|               A|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99537435|            A|           G| 0.0336|        NA|      NA|      NA|  NA|            NA|                     NA| rs75635821|
# |1_99537648_T_G| rs78948828|       1|99537648|              T|               G|     NA|           NA|         NA|         NA|                        NA|     11|         1|          99537648|            T|           G| 0.1342|        NA|      NA|      NA|  NA|            NA|                     NA| rs78948828|
# | 1_9940342_T_A|  rs1237370|       1| 9940342|              T|               A|     NA|           NA|         NA|         NA|                        NA|      5|         1|           9940342|            A|           T| 0.3385|        NA|      NA|      NA|  NA|            NA|                     NA|  rs1237370|
# |1_99539170_G_A|  rs6682190|       1|99539170|              G|               A|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99539170|            A|           G| 0.5989|        NA|      NA|      NA|  NA|            NA|                     NA|  rs6682190|
# |1_99539674_A_T|  rs6697069|       1|99539674|              A|               T|     NA|           NA|         NA|         NA|                        NA|      6|         1|          99539674|            A|           T|0.02979|        NA|      NA|      NA|  NA|            NA|                     NA|  rs6697069|
# |1_99539921_G_A| rs12069019|       1|99539921|              G|               A|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99539921|            A|           G| 0.7602|        NA|      NA|      NA|  NA|            NA|                     NA| rs12069019|
# |1_99540561_G_A|  rs6686057|       1|99540561|              G|               A|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99540561|            A|           G| 0.8952|        NA|      NA|      NA|  NA|            NA|                     NA|  rs6686057|
# |1_99541178_C_T| rs55725529|       1|99541178|              C|               T|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99541178|            T|           C| 0.5069|        NA|      NA|      NA|  NA|            NA|                     NA| rs55725529|
# |1_99541898_C_T| rs12082355|       1|99541898|              C|               T|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99541898|            T|           C|   0.75|        NA|      NA|      NA|  NA|            NA|                     NA| rs12082355|
# |1_99542185_A_G| rs12067343|       1|99542185|              A|               G|     NA|           NA|         NA|         NA|                        NA|     11|         1|          99542185|            A|           G| 0.5987|        NA|      NA|      NA|  NA|            NA|                     NA| rs12067343|
# |1_99543051_A_C| rs11166268|       1|99543051|              A|               C|     NA|           NA|         NA|         NA|                        NA|     11|         1|          99543051|            A|           C| 0.2104|        NA|      NA|      NA|  NA|            NA|                     NA| rs11166268|
# |1_99543431_C_A| rs11166269|       1|99543431|              C|               A|     NA|           NA|         NA|         NA|                        NA|     10|         1|          99543431|            A|           C| 0.6676|        NA|      NA|      NA|  NA|            NA|                     NA| rs11166269|
# +--------------+-----------+--------+--------+---------------+----------------+-------+-------------+-----------+-----------+--------------------------+-------+----------+------------------+-------------+------------+-------+----------+--------+--------+----+--------------+-----------------------+-----------+
# only showing top 20 rows

# %%
|

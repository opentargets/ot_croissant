# %%
import pandas as pd
from typing import Any
import json 

# Extract table from spreadsheet:
df = (
    pd.read_csv('https://docs.google.com/spreadsheets/d/1G3zq-aJg3uKBz3VZUvGV8yYVrECtpQ9SJoGX6X3B-ms/export?format=csv', sep=',')
    .loc[lambda df: df.output.notna()]
)
print(df.head())

# Convert table to mapping:
datasoruce_mapping = (
    df[['output', 'niceName', 'description']]
    .set_index(
        pd.Series(df.datasourceId.to_list())
    )
    .to_dict(orient='index')
)

datasoruce_mapping
# Out:
#          datasourceId                    source configuration  \
# 0   cancer_biomarkers  cancerbiomarkers.json.gz            OK
# 1  cancer_gene_census            cosmic.json.gz           OK
# 2              chembl            chembl.json.gz            OK
# 3             clingen           clingen.json.gz            OK
# 4              crispr            crispr.json.gz            OK
#
#   Direction of effect  run time (s) isScoreOK    valid old valid invalid  \
# 0                 NaN          47.0        OK    1,300     1,300      49
# 1                  OK          55.0        OK   91,572    91,572  11,300
# 2                  OK          27.0        OK  573,103   573,103  18,243
# 3                 NaN          18.0        OK    3,047     3,047     292
# 4                 NaN          52.0        OK      517       517       0
#
#   old invalid comment                       output  \
# 0          49     NaN   evidence_cancer_biomarkers
# 1      11,300     NaN  evidence_cancer_gene_census
# 2      18,243     NaN              evidence_chembl
# 3         292     NaN             evidence_clingen
# 4           0     NaN              evidence_crispr
#
#                       niceName  \
# 0    Cancer biomarker evidence
# 1  Cancer Gene Census evidence
# 2              ChEMBL evidence
# 3             ClinGen evidence
# 4        ProjectScore evidence
#
#                                          description
# 0  Disease-target evidence based on cancer biomar...
# 1  Disease-target evidence based on Cancer Gene C...
# 2  Disease-target evidence based on drug indicati...
# 3  Disease-target evidence from Gene–Disease Vali...
# 4  Diease-target evidence from unified analysis o...
# {'cancer_biomarkers': {'output': 'evidence_cancer_biomarkers',
#   'niceName': 'Cancer biomarker evidence',
#   'description': 'Disease-target evidence based on cancer biomarkers from the Cancer Genome Interpreter'},
#  'cancer_gene_census': {'output': 'evidence_cancer_gene_census',
#   'niceName': 'Cancer Gene Census evidence',
#   'description': 'Disease-target evidence based on Cancer Gene Census provided by COSMIC'},
#  'chembl': {'output': 'evidence_chembl',
#   'niceName': 'ChEMBL evidence',
#   'description': 'Disease-target evidence based on drug indications, clinical trials and mechanism of action provided by ChEMBL'},
#  'clingen': {'output': 'evidence_clingen',
#   'niceName': 'ClinGen evidence',
#   'description': 'Disease-target evidence from Gene–Disease Validity Curation of ClinGen'},
#  'crispr': {'output': 'evidence_crispr',
#   'niceName': 'ProjectScore evidence',
#   'description': 'Diease-target evidence from unified analysis of whole-genome CRISPR/Cas9 screens from ProjectScore project'},
#  'crispr_screen': {'output': 'evidence_crispr_screen',
#   'niceName': 'CRISP screen evidence',
#   'description': 'Disease-target evidence derived from systematic gene perturation assays of CRISPR knock-out screens'},
#  'encore': {'output': 'evidence_encore',
#   'niceName': 'Open Targets - Encore evidence',
#   'description': 'Disease-target evidence based on somatic variation from ClinVar, provided by the European Variation Archive'},
#  'europepmc': {'output': 'evidence_europepmc',
#   'niceName': 'EuropePMC evidence',
#   'description': 'Disease-target evidence derived from literature mining provided by Europe PMC'},
#  'eva': {'output': 'evidence_eva',
#   'niceName': 'ClinVar germ-line evidence',
#   'description': 'Disease-target evidence based on germline variation from ClinVar, provided by the European Variation Archive'},
#  'eva_somatic': {'output': 'evidence_eva_somatic',
#   'niceName': 'ClinVar somatic evidence',
#   'description': 'Disease-target evidence based on somatic variation from ClinVar, provided by the European Variation Archive'},
#  'expression_atlas': {'output': 'evidence_expression_atlas',
#   'niceName': 'Differential expression evidence',
#   'description': 'Disease-target evidence based on differential expression data provided by Expression Atlas'},
#  'gene_burden': {'output': 'evidence_gene_burden',
#   'niceName': 'Gene burden evidence',
#   'description': 'Disease-target evidence based on testing aggregated effect of variants, curated from the literature by the Open Targets team'},
#  'gene2phenotype': {'output': 'evidence_gene2phenotype',
#   'niceName': 'Gene2Phenotype evidence',
#   'description': 'Disease-target evidence curated by the Gene2Phenotype consortium'},
#  'genomics_england': {'output': 'evidence_genomics_england',
#   'niceName': 'Genomics England - PanelApp evidence',
#   'description': 'Curated disease-target evidence provided by Genomics England PanelApp'},
#  'gwas_credible_set': {'output': 'evidence_gwas_credible_sets',
#   'niceName': 'GWAS credible-set evidence',
#   'description': 'Disease-target evidence based on Locus-to-Gene prediction on GWAS credible sets'},
#  'impc': {'output': 'evidence_impc',
#   'niceName': 'IMPC evidence',
#   'description': 'Disease-target evidence based on mouse knock-out models, where mouse phenotypes are mapped to human diseases by PhenoDigm algorithm. Data provided by IMPC'},
#  'intogen': {'output': 'evidence_intogen',
#   'niceName': 'IntOGen evidence',
#   'description': 'Cancer-driver gene evidence based on the analysis of large-scale mutational data from IntOGen'},
#  'orphanet': {'output': 'evidence_orphanet',
#   'niceName': 'Orphanet evidence',
#   'description': 'Curated collection of rare disase-target evidence from Orphanet'},
#  'ot_crispr': {'output': 'evidence_ot_crispr',
#   'niceName': 'Open Targets - CRISPR screen evidence',
#   'description': 'Pre-publication CRISPR/Cas9 perturation screens provided by Open Targets experimental projects'},
#  'ot_crispr_validation': {'output': 'evidence_ot_crispr_validation',
#   'niceName': 'Open Targets - Validation Lab evidence',
#   'description': 'Disease-target evidence derived from CRISPR/Cas9 perturation screens provided by Open Targets Validation lab'},
#  'reactome': {'output': 'evidence_reactome',
#   'niceName': 'Reactome evidence',
#   'description': 'Manually curated disease-target evidence based on reaction pathways sourced from Reactome'},
#  'uniprot_literature': {'output': 'evidence_uniprot_literature',
#   'niceName': 'Uniprot literature evidence',
#   'description': 'Protein-disease evidence based on literature curated by the Uniprot team'},
#  'uniprot_variants': {'output': 'evidence_uniprot_variants',
#   'niceName': 'Uniprot variants evidence',
#   'description': 'Disease-target evidence based on disease causing protein sequence alteration curated by the Uniprot team'}}

# %%
def process_dataset(output: str, nice_name:str, description:str) -> dict[str,Any]:
    return {
        "id": output,
        "nice_name": nice_name,
        "key": [ f"{output}/id"],
        "description": description,
        "tags": ["Target-Disease"]
    }

print(
    json.dumps(
        [
            process_dataset(value['output'], value['niceName'], value['description'])
            for value in datasoruce_mapping.values()
        ],
        indent=2
    )
)
# Out:
# [
#   {
#     "id": "evidence_cancer_biomarkers",
#     "nice_name": "Cancer biomarker evidence",
#     "key": [
#       "evidence_cancer_biomarkers/id"
#     ],
#     "description": "Disease-target evidence based on cancer biomarkers from the Cancer Genome Interpreter",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_cancer_gene_census",
#     "nice_name": "Cancer Gene Census evidence",
#     "key": [
#       "evidence_cancer_gene_census/id"
#     ],
#     "description": "Disease-target evidence based on Cancer Gene Census provided by COSMIC",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_chembl",
#     "nice_name": "ChEMBL evidence",
#     "key": [
#       "evidence_chembl/id"
#     ],
#     "description": "Disease-target evidence based on drug indications, clinical trials and mechanism of action provided by ChEMBL",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_clingen",
#     "nice_name": "ClinGen evidence",
#     "key": [
#       "evidence_clingen/id"
#     ],
#     "description": "Disease-target evidence from Gene\u2013Disease Validity Curation of ClinGen",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_crispr",
#     "nice_name": "ProjectScore evidence",
#     "key": [
#       "evidence_crispr/id"
#     ],
#     "description": "Diease-target evidence from unified analysis of whole-genome CRISPR/Cas9 screens from ProjectScore project",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_crispr_screen",
#     "nice_name": "CRISP screen evidence",
#     "key": [
#       "evidence_crispr_screen/id"
#     ],
#     "description": "Disease-target evidence derived from systematic gene perturation assays of CRISPR knock-out screens",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_encore",
#     "nice_name": "Open Targets - Encore evidence",
#     "key": [
#       "evidence_encore/id"
#     ],
#     "description": "Disease-target evidence based on somatic variation from ClinVar, provided by the European Variation Archive",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_europepmc",
#     "nice_name": "EuropePMC evidence",
#     "key": [
#       "evidence_europepmc/id"
#     ],
#     "description": "Disease-target evidence derived from literature mining provided by Europe PMC",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_eva",
#     "nice_name": "ClinVar germ-line evidence",
#     "key": [
#       "evidence_eva/id"
#     ],
#     "description": "Disease-target evidence based on germline variation from ClinVar, provided by the European Variation Archive",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_eva_somatic",
#     "nice_name": "ClinVar somatic evidence",
#     "key": [
#       "evidence_eva_somatic/id"
#     ],
#     "description": "Disease-target evidence based on somatic variation from ClinVar, provided by the European Variation Archive",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_expression_atlas",
#     "nice_name": "Differential expression evidence",
#     "key": [
#       "evidence_expression_atlas/id"
#     ],
#     "description": "Disease-target evidence based on differential expression data provided by Expression Atlas",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_gene_burden",
#     "nice_name": "Gene burden evidence",
#     "key": [
#       "evidence_gene_burden/id"
#     ],
#     "description": "Disease-target evidence based on testing aggregated effect of variants, curated from the literature by the Open Targets team",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_gene2phenotype",
#     "nice_name": "Gene2Phenotype evidence",
#     "key": [
#       "evidence_gene2phenotype/id"
#     ],
#     "description": "Disease-target evidence curated by the Gene2Phenotype consortium",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_genomics_england",
#     "nice_name": "Genomics England - PanelApp evidence",
#     "key": [
#       "evidence_genomics_england/id"
#     ],
#     "description": "Curated disease-target evidence provided by Genomics England PanelApp",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_gwas_credible_sets",
#     "nice_name": "GWAS credible-set evidence",
#     "key": [
#       "evidence_gwas_credible_sets/id"
#     ],
#     "description": "Disease-target evidence based on Locus-to-Gene prediction on GWAS credible sets",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_impc",
#     "nice_name": "IMPC evidence",
#     "key": [
#       "evidence_impc/id"
#     ],
#     "description": "Disease-target evidence based on mouse knock-out models, where mouse phenotypes are mapped to human diseases by PhenoDigm algorithm. Data provided by IMPC",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_intogen",
#     "nice_name": "IntOGen evidence",
#     "key": [
#       "evidence_intogen/id"
#     ],
#     "description": "Cancer-driver gene evidence based on the analysis of large-scale mutational data from IntOGen",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_orphanet",
#     "nice_name": "Orphanet evidence",
#     "key": [
#       "evidence_orphanet/id"
#     ],
#     "description": "Curated collection of rare disase-target evidence from Orphanet",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_ot_crispr",
#     "nice_name": "Open Targets - CRISPR screen evidence",
#     "key": [
#       "evidence_ot_crispr/id"
#     ],
#     "description": "Pre-publication CRISPR/Cas9 perturation screens provided by Open Targets experimental projects",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_ot_crispr_validation",
#     "nice_name": "Open Targets - Validation Lab evidence",
#     "key": [
#       "evidence_ot_crispr_validation/id"
#     ],
#     "description": "Disease-target evidence derived from CRISPR/Cas9 perturation screens provided by Open Targets Validation lab",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_reactome",
#     "nice_name": "Reactome evidence",
#     "key": [
#       "evidence_reactome/id"
#     ],
#     "description": "Manually curated disease-target evidence based on reaction pathways sourced from Reactome",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_uniprot_literature",
#     "nice_name": "Uniprot literature evidence",
#     "key": [
#       "evidence_uniprot_literature/id"
#     ],
#     "description": "Protein-disease evidence based on literature curated by the Uniprot team",
#     "tags": [
#       "Target-Disease"
#     ]
#   },
#   {
#     "id": "evidence_uniprot_variants",
#     "nice_name": "Uniprot variants evidence",
#     "key": [
#       "evidence_uniprot_variants/id"
#     ],
#     "description": "Disease-target evidence based on disease causing protein sequence alteration curated by the Uniprot team",
#     "tags": [
#       "Target-Disease"
#     ]
#   }
# ]

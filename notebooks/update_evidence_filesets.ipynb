# %%
from pyspark.sql import DataFrame, SparkSession, functions as f
import pandas as pd
import json
from urllib.error import URLError

# https://docs.google.com/spreadsheets/d/132SKHMoaJePu4nTlBnQwfaz3dhfJiKmJUujfYkzXMdI/edit?gid=179018892#gid=179018892

def get_evidence_datasets() -> pd.DataFrame:
    # Evidence datasets:
    spreadsheet_url = f'https://docs.google.com/spreadsheets/d/1G3zq-aJg3uKBz3VZUvGV8yYVrECtpQ9SJoGX6X3B-ms/export?format=csv'

    try:
        df = pd.read_csv(spreadsheet_url, sep=',')
    except URLError:
        df = pd.read_csv('dataset_name_mapping.csv')

    # Extract table from spreadsheet:
    return (
        df
        .loc[lambda df: df.output.notna()]
        [['output', 'datasourceId']]
    )

def get_full_croissant(gid:str) -> pd.DataFrame:
    """
    (
        pd.read_csv(full_croissant_description_url,  sep=',')
        .to_csv('full_croissant_description.csv', sep=',', index=False)
    )
    """
    # Evidence datasets:
    full_croissant_description_url = f'https://docs.google.com/spreadsheets/d/132SKHMoaJePu4nTlBnQwfaz3dhfJiKmJUujfYkzXMdI/export?gid={gid}&format=csv'

    try:
        df = pd.read_csv(full_croissant_description_url, sep=',')
    except URLError:
        print('reading from backup: full_croissant_description.csv')
        df = pd.read_csv('full_croissant_description.csv')

    # Extract table from spreadsheet:
    return df

def get_full_evidence(gid: str) -> pd.DataFrame:
    return (
        get_full_croissant(gid)
        .loc[lambda df: df.dataset_name == 'evidence']
        .assign(
            field_join = lambda x: x.field_id.str.extract(r'\/(.+)$')
        )
        .drop(['dataset_name', 'Example', 'column_name', 'field_id'], axis=1)
    )

# 25.09:
gid = '179018892'

# Get a list of evidence datasets:
dataset_list = get_evidence_datasets()

# Reading a piece of dataset representing the schema of the entire dataset:
spark = SparkSession.builder.getOrCreate()

data_folder = '/Users/dsuveges/project_data/25.09/output'

# %%
dataset_list.head() #to_csv('dataset_name_mapping.csv', sep=',', index=False)
# Out:
#                         output        datasourceId
# 0   evidence_cancer_biomarkers   cancer_biomarkers
# 1  evidence_cancer_gene_census  cancer_gene_census
# 2              evidence_chembl              chembl
# 3             evidence_clingen             clingen
# 4              evidence_crispr              crispr

# %%
# Processing a field in the spark schema:
# Processing a field in the spark schema:
def process_fields(
    fields: dict[str, str], 
    parent: str, 
    dataset_name: str,
    schema: list[dict[str,str]] | None = None,
) -> list[dict[str, str]]:
    if schema is None:
        schema = []

    # Iterating over all fields of the schema:
    for field in fields.get('fields'):

        name = field.get('name')
        # Recurse for nested structs:
        if isinstance(field['type'], dict):
            if field['type']['type'] == 'struct':
                # Call self:
                schema = schema + process_fields(
                    field['type'], 
                    f'{parent}/{name}',
                    dataset_name,
                    [],
                )
            elif isinstance(field['type']['elementType'], dict):
                # Call self:
                schema = schema + process_fields(
                    field["type"]['elementType'], 
                    f'{parent}/{name}',
                    dataset_name,
                    [],
                )
        # Capture atomic column types:
        schema.append(
            {
                'dataset_name': dataset_name,
                'field_id': f'{parent}/{name}',
                'column_name': name,
            }
        )
    # Return captured schema:
    return schema


def generate_schema_representation(
    output: str,
    datasourceId: str
) -> pd.DataFrame:

    # Read dataset:
    try:
        df = spark.read.parquet(f'{data_folder}/{output}')
    except:
        print(f'missing dataset: {data_folder}/{output}')
        return None

    # Get its schema:
    data = json.loads(df.schema.json())

    # We iterate over the schema and collect field names that we will be able to annotate on the spreadsheet:
    schema = process_fields(
        data, 
        output,
        output
    )

    # Process and return schema representation:
    return (
        pd.DataFrame(schema)
        .assign(
            field_join = lambda x: x.field_id.str.extract(r'\/(.+)$')
        )
    )



# generate_schema_representation(**dataset)    
new_evidence_collated = pd.concat([
    generate_schema_representation(**row)
    for _, row in 
    dataset_list.iterrows()
])

# print(len(new_evidence_collated))
# new_evidence_collated.head()
# Out:
# parent: evidence_cancer_biomarkers name: id
# parent: evidence_cancer_biomarkers name: targetFromSourceId
# parent: evidence_cancer_biomarkers name: diseaseFromSourceMappedId
# parent: evidence_cancer_biomarkers name: biomarkerName
# parent: evidence_cancer_biomarkers name: biomarkers
# dict
# struct
# parent: evidence_cancer_biomarkers/biomarkers name: geneExpression
# dict
# array of struct
# parent: evidence_cancer_biomarkers/biomarkers/geneExpression name: id
# parent: evidence_cancer_biomarkers/biomarkers/geneExpression name: name
# parent: evidence_cancer_biomarkers/biomarkers name: geneticVariation
# dict
# array of struct
# parent: evidence_cancer_biomarkers/biomarkers/geneticVariation name: functionalConsequenceId
# parent: evidence_cancer_biomarkers/biomarkers/geneticVariation name: id
# parent: evidence_cancer_biomarkers/biomarkers/geneticVariation name: name
# parent: evidence_cancer_biomarkers name: confidence
# parent: evidence_cancer_biomarkers name: datasourceId
# parent: evidence_cancer_biomarkers name: datatypeId
# parent: evidence_cancer_biomarkers name: diseaseFromSource
# parent: evidence_cancer_biomarkers name: drugFromSource
# parent: evidence_cancer_biomarkers name: drugId
# parent: evidence_cancer_biomarkers name: drugResponse
# parent: evidence_cancer_biomarkers name: literature
# dict
# parent: evidence_cancer_biomarkers name: urls
# dict
# array of struct
# parent: evidence_cancer_biomarkers/urls name: niceName
# parent: evidence_cancer_biomarkers/urls name: url
# parent: evidence_cancer_biomarkers name: qualityControls
# dict
# parent: evidence_cancer_biomarkers name: diseaseId
# parent: evidence_cancer_biomarkers name: targetId
# parent: evidence_cancer_biomarkers name: publicationDate
# parent: evidence_cancer_biomarkers name: evidenceDate
# parent: evidence_cancer_biomarkers name: score
# parent: evidence_cancer_gene_census name: targetId
# parent: evidence_cancer_gene_census name: id
# parent: evidence_cancer_gene_census name: targetFromSourceId
# parent: evidence_cancer_gene_census name: diseaseFromSourceMappedId
# parent: evidence_cancer_gene_census name: datasourceId
# parent: evidence_cancer_gene_census name: datatypeId
# parent: evidence_cancer_gene_census name: diseaseFromSourceId
# parent: evidence_cancer_gene_census name: literature
# dict
# parent: evidence_cancer_gene_census name: mutatedSamples
# dict
# array of struct
# parent: evidence_cancer_gene_census/mutatedSamples name: functionalConsequenceId
# parent: evidence_cancer_gene_census/mutatedSamples name: numberMutatedSamples
# parent: evidence_cancer_gene_census/mutatedSamples name: numberSamplesTested
# parent: evidence_cancer_gene_census/mutatedSamples name: numberSamplesWithMutationType
# parent: evidence_cancer_gene_census name: resourceScore
# parent: evidence_cancer_gene_census name: studyId
# parent: evidence_cancer_gene_census name: qualityControls
# dict
# parent: evidence_cancer_gene_census name: diseaseId
# parent: evidence_cancer_gene_census name: publicationDate
# parent: evidence_cancer_gene_census name: evidenceDate
# parent: evidence_cancer_gene_census name: score
# parent: evidence_cancer_gene_census name: directionOnTrait
# parent: evidence_cancer_gene_census name: directionOnTarget
# parent: evidence_chembl name: targetId
# parent: evidence_chembl name: drugId
# parent: evidence_chembl name: targetFromSourceId
# parent: evidence_chembl name: diseaseFromSourceMappedId
# parent: evidence_chembl name: clinicalPhase
# parent: evidence_chembl name: clinicalStatus
# parent: evidence_chembl name: cohortPhenotypes
# dict
# parent: evidence_chembl name: datasourceId
# parent: evidence_chembl name: datatypeId
# parent: evidence_chembl name: diseaseFromSource
# parent: evidence_chembl name: studyId
# parent: evidence_chembl name: studyStartDate
# parent: evidence_chembl name: studyStopReason
# parent: evidence_chembl name: studyStopReasonCategories
# dict
# parent: evidence_chembl name: targetFromSource
# parent: evidence_chembl name: urls
# dict
# array of struct
# parent: evidence_chembl/urls name: niceName
# parent: evidence_chembl/urls name: url
# parent: evidence_chembl name: qualityControls
# dict
# parent: evidence_chembl name: diseaseId
# parent: evidence_chembl name: id
# parent: evidence_chembl name: evidenceDate
# parent: evidence_chembl name: score
# parent: evidence_chembl name: directionOnTrait
# parent: evidence_chembl name: directionOnTarget
# parent: evidence_clingen name: targetFromSourceId
# parent: evidence_clingen name: diseaseFromSourceMappedId
# parent: evidence_clingen name: allelicRequirements
# dict
# parent: evidence_clingen name: confidence
# parent: evidence_clingen name: datasourceId
# parent: evidence_clingen name: datatypeId
# parent: evidence_clingen name: diseaseFromSource
# parent: evidence_clingen name: diseaseFromSourceId
# parent: evidence_clingen name: releaseDate
# parent: evidence_clingen name: studyId
# parent: evidence_clingen name: urls
# dict
# array of struct
# parent: evidence_clingen/urls name: url
# parent: evidence_clingen name: qualityControls
# dict
# parent: evidence_clingen name: diseaseId
# parent: evidence_clingen name: targetId
# parent: evidence_clingen name: id
# parent: evidence_clingen name: evidenceDate
# parent: evidence_clingen name: score
# parent: evidence_crispr name: id
# parent: evidence_crispr name: targetFromSourceId
# parent: evidence_crispr name: diseaseFromSourceMappedId
# parent: evidence_crispr name: datasourceId
# parent: evidence_crispr name: datatypeId
# parent: evidence_crispr name: diseaseCellLines
# dict
# array of struct
# parent: evidence_crispr/diseaseCellLines name: id
# parent: evidence_crispr/diseaseCellLines name: name
# parent: evidence_crispr/diseaseCellLines name: tissue
# parent: evidence_crispr/diseaseCellLines name: tissueId
# parent: evidence_crispr name: diseaseFromSource
# parent: evidence_crispr name: literature
# dict
# parent: evidence_crispr name: resourceScore
# parent: evidence_crispr name: targetFromSource
# parent: evidence_crispr name: qualityControls
# dict
# parent: evidence_crispr name: diseaseId
# parent: evidence_crispr name: targetId
# parent: evidence_crispr name: publicationDate
# parent: evidence_crispr name: evidenceDate
# parent: evidence_crispr name: score
# parent: evidence_crispr_screen name: id
# parent: evidence_crispr_screen name: targetFromSourceId
# parent: evidence_crispr_screen name: diseaseFromSourceMappedId
# parent: evidence_crispr_screen name: cellType
# parent: evidence_crispr_screen name: contrast
# parent: evidence_crispr_screen name: crisprScreenLibrary
# parent: evidence_crispr_screen name: datasourceId
# parent: evidence_crispr_screen name: datatypeId
# parent: evidence_crispr_screen name: diseaseFromSource
# parent: evidence_crispr_screen name: geneticBackground
# parent: evidence_crispr_screen name: literature
# dict
# parent: evidence_crispr_screen name: log2FoldChangeValue
# parent: evidence_crispr_screen name: projectId
# parent: evidence_crispr_screen name: resourceScore
# parent: evidence_crispr_screen name: statisticalTestTail
# parent: evidence_crispr_screen name: studyId
# parent: evidence_crispr_screen name: studyOverview
# parent: evidence_crispr_screen name: qualityControls
# dict
# parent: evidence_crispr_screen name: diseaseId
# parent: evidence_crispr_screen name: targetId
# parent: evidence_crispr_screen name: publicationDate
# parent: evidence_crispr_screen name: evidenceDate
# parent: evidence_crispr_screen name: score
# parent: evidence_encore name: targetFromSourceId
# parent: evidence_encore name: diseaseFromSourceMappedId
# parent: evidence_encore name: biomarkerList
# dict
# array of struct
# parent: evidence_encore/biomarkerList name: description
# parent: evidence_encore/biomarkerList name: name
# parent: evidence_encore name: datasourceId
# parent: evidence_encore name: datatypeId
# parent: evidence_encore name: diseaseCellLines
# dict
# array of struct
# parent: evidence_encore/diseaseCellLines name: id
# parent: evidence_encore/diseaseCellLines name: name
# parent: evidence_encore/diseaseCellLines name: tissue
# parent: evidence_encore/diseaseCellLines name: tissueId
# parent: evidence_encore name: diseaseFromSource
# parent: evidence_encore name: geneInteractionType
# parent: evidence_encore name: geneticInteractionPValue
# parent: evidence_encore name: geneticInteractionScore
# parent: evidence_encore name: interactingTargetFromSourceId
# parent: evidence_encore name: interactingTargetRole
# parent: evidence_encore name: phenotypicConsequenceFDR
# parent: evidence_encore name: phenotypicConsequenceLogFoldChange
# parent: evidence_encore name: phenotypicConsequencePValue
# parent: evidence_encore name: projectDescription
# parent: evidence_encore name: projectId
# parent: evidence_encore name: releaseDate
# parent: evidence_encore name: releaseVersion
# parent: evidence_encore name: statisticalMethod
# parent: evidence_encore name: targetRole
# parent: evidence_encore name: qualityControls
# dict
# parent: evidence_encore name: diseaseId
# parent: evidence_encore name: targetId
# parent: evidence_encore name: id
# parent: evidence_encore name: evidenceDate
# parent: evidence_encore name: score
# parent: evidence_europepmc name: id
# parent: evidence_europepmc name: targetFromSourceId
# parent: evidence_europepmc name: diseaseFromSourceMappedId
# parent: evidence_europepmc name: datasourceId
# parent: evidence_europepmc name: datatypeId
# parent: evidence_europepmc name: literature
# dict
# parent: evidence_europepmc name: pmcIds
# dict
# parent: evidence_europepmc name: publicationYear
# parent: evidence_europepmc name: resourceScore
# parent: evidence_europepmc name: textMiningSentences
# dict
# array of struct
# parent: evidence_europepmc/textMiningSentences name: dEnd
# parent: evidence_europepmc/textMiningSentences name: dStart
# parent: evidence_europepmc/textMiningSentences name: section
# parent: evidence_europepmc/textMiningSentences name: tEnd
# parent: evidence_europepmc/textMiningSentences name: tStart
# parent: evidence_europepmc/textMiningSentences name: text
# parent: evidence_europepmc name: qualityControls
# dict
# parent: evidence_europepmc name: diseaseId
# parent: evidence_europepmc name: targetId
# parent: evidence_europepmc name: publicationDate
# parent: evidence_europepmc name: evidenceDate
# parent: evidence_europepmc name: score
# parent: evidence_eva name: targetId
# parent: evidence_eva name: id
# parent: evidence_eva name: targetFromSourceId
# parent: evidence_eva name: diseaseFromSourceMappedId
# parent: evidence_eva name: alleleOrigins
# dict
# parent: evidence_eva name: allelicRequirements
# dict
# parent: evidence_eva name: clinicalSignificances
# dict
# parent: evidence_eva name: cohortPhenotypes
# dict
# parent: evidence_eva name: confidence
# parent: evidence_eva name: datasourceId
# parent: evidence_eva name: datatypeId
# parent: evidence_eva name: diseaseFromSource
# parent: evidence_eva name: diseaseFromSourceId
# parent: evidence_eva name: literature
# dict
# parent: evidence_eva name: releaseDate
# parent: evidence_eva name: studyId
# parent: evidence_eva name: variantFromSourceId
# parent: evidence_eva name: variantFunctionalConsequenceId
# parent: evidence_eva name: variantHgvsId
# parent: evidence_eva name: variantId
# parent: evidence_eva name: variantRsId
# parent: evidence_eva name: qualityControls
# dict
# parent: evidence_eva name: diseaseId
# parent: evidence_eva name: publicationDate
# parent: evidence_eva name: evidenceDate
# parent: evidence_eva name: score
# parent: evidence_eva name: directionOnTrait
# parent: evidence_eva name: directionOnTarget
# parent: evidence_eva_somatic name: targetId
# parent: evidence_eva_somatic name: id
# parent: evidence_eva_somatic name: targetFromSourceId
# parent: evidence_eva_somatic name: diseaseFromSourceMappedId
# parent: evidence_eva_somatic name: alleleOrigins
# dict
# parent: evidence_eva_somatic name: allelicRequirements
# dict
# parent: evidence_eva_somatic name: clinicalSignificances
# dict
# parent: evidence_eva_somatic name: cohortPhenotypes
# dict
# parent: evidence_eva_somatic name: confidence
# parent: evidence_eva_somatic name: datasourceId
# parent: evidence_eva_somatic name: datatypeId
# parent: evidence_eva_somatic name: diseaseFromSource
# parent: evidence_eva_somatic name: diseaseFromSourceId
# parent: evidence_eva_somatic name: literature
# dict
# parent: evidence_eva_somatic name: releaseDate
# parent: evidence_eva_somatic name: studyId
# parent: evidence_eva_somatic name: variantFromSourceId
# parent: evidence_eva_somatic name: variantFunctionalConsequenceId
# parent: evidence_eva_somatic name: variantHgvsId
# parent: evidence_eva_somatic name: variantId
# parent: evidence_eva_somatic name: variantRsId
# parent: evidence_eva_somatic name: qualityControls
# dict
# parent: evidence_eva_somatic name: diseaseId
# parent: evidence_eva_somatic name: publicationDate
# parent: evidence_eva_somatic name: evidenceDate
# parent: evidence_eva_somatic name: score
# parent: evidence_eva_somatic name: directionOnTrait
# parent: evidence_eva_somatic name: directionOnTarget
# parent: evidence_expression_atlas name: id
# parent: evidence_expression_atlas name: targetFromSourceId
# parent: evidence_expression_atlas name: diseaseFromSourceMappedId
# parent: evidence_expression_atlas name: biosamplesFromSource
# dict
# parent: evidence_expression_atlas name: confidence
# parent: evidence_expression_atlas name: contrast
# parent: evidence_expression_atlas name: datasourceId
# parent: evidence_expression_atlas name: datatypeId
# parent: evidence_expression_atlas name: literature
# dict
# parent: evidence_expression_atlas name: log2FoldChangePercentileRank
# parent: evidence_expression_atlas name: log2FoldChangeValue
# parent: evidence_expression_atlas name: resourceScore
# parent: evidence_expression_atlas name: studyId
# parent: evidence_expression_atlas name: studyOverview
# parent: evidence_expression_atlas name: qualityControls
# dict
# parent: evidence_expression_atlas name: diseaseId
# parent: evidence_expression_atlas name: targetId
# parent: evidence_expression_atlas name: publicationDate
# parent: evidence_expression_atlas name: evidenceDate
# parent: evidence_expression_atlas name: score
# parent: evidence_gene_burden name: targetId
# parent: evidence_gene_burden name: id
# parent: evidence_gene_burden name: targetFromSourceId
# parent: evidence_gene_burden name: diseaseFromSourceMappedId
# parent: evidence_gene_burden name: allelicRequirements
# dict
# parent: evidence_gene_burden name: ancestry
# parent: evidence_gene_burden name: ancestryId
# parent: evidence_gene_burden name: beta
# parent: evidence_gene_burden name: betaConfidenceIntervalLower
# parent: evidence_gene_burden name: betaConfidenceIntervalUpper
# parent: evidence_gene_burden name: cohortId
# parent: evidence_gene_burden name: datasourceId
# parent: evidence_gene_burden name: datatypeId
# parent: evidence_gene_burden name: diseaseFromSource
# parent: evidence_gene_burden name: diseaseFromSourceId
# parent: evidence_gene_burden name: literature
# dict
# parent: evidence_gene_burden name: oddsRatio
# parent: evidence_gene_burden name: oddsRatioConfidenceIntervalLower
# parent: evidence_gene_burden name: oddsRatioConfidenceIntervalUpper
# parent: evidence_gene_burden name: pValueExponent
# parent: evidence_gene_burden name: pValueMantissa
# parent: evidence_gene_burden name: projectId
# parent: evidence_gene_burden name: releaseVersion
# parent: evidence_gene_burden name: resourceScore
# parent: evidence_gene_burden name: sex
# dict
# parent: evidence_gene_burden name: statisticalMethod
# parent: evidence_gene_burden name: statisticalMethodOverview
# parent: evidence_gene_burden name: studyCases
# parent: evidence_gene_burden name: studyCasesWithQualifyingVariants
# parent: evidence_gene_burden name: studySampleSize
# parent: evidence_gene_burden name: urls
# dict
# array of struct
# parent: evidence_gene_burden/urls name: niceName
# parent: evidence_gene_burden/urls name: url
# parent: evidence_gene_burden name: qualityControls
# dict
# parent: evidence_gene_burden name: diseaseId
# parent: evidence_gene_burden name: publicationDate
# parent: evidence_gene_burden name: evidenceDate
# parent: evidence_gene_burden name: score
# parent: evidence_gene_burden name: directionOnTrait
# parent: evidence_gene_burden name: directionOnTarget
# parent: evidence_gene2phenotype name: targetId
# parent: evidence_gene2phenotype name: id
# parent: evidence_gene2phenotype name: targetFromSourceId
# parent: evidence_gene2phenotype name: diseaseFromSourceMappedId
# parent: evidence_gene2phenotype name: allelicRequirements
# dict
# parent: evidence_gene2phenotype name: confidence
# parent: evidence_gene2phenotype name: datasourceId
# parent: evidence_gene2phenotype name: datatypeId
# parent: evidence_gene2phenotype name: diseaseFromSource
# parent: evidence_gene2phenotype name: diseaseFromSourceId
# parent: evidence_gene2phenotype name: literature
# dict
# parent: evidence_gene2phenotype name: studyId
# parent: evidence_gene2phenotype name: variantFunctionalConsequenceId
# parent: evidence_gene2phenotype name: qualityControls
# dict
# parent: evidence_gene2phenotype name: diseaseId
# parent: evidence_gene2phenotype name: publicationDate
# parent: evidence_gene2phenotype name: evidenceDate
# parent: evidence_gene2phenotype name: score
# parent: evidence_gene2phenotype name: directionOnTrait
# parent: evidence_gene2phenotype name: directionOnTarget
# parent: evidence_genomics_england name: id
# parent: evidence_genomics_england name: targetFromSourceId
# parent: evidence_genomics_england name: diseaseFromSourceMappedId
# parent: evidence_genomics_england name: allelicRequirements
# dict
# parent: evidence_genomics_england name: cohortPhenotypes
# dict
# parent: evidence_genomics_england name: confidence
# parent: evidence_genomics_england name: datasourceId
# parent: evidence_genomics_england name: datatypeId
# parent: evidence_genomics_england name: diseaseFromSource
# parent: evidence_genomics_england name: diseaseFromSourceId
# parent: evidence_genomics_england name: literature
# dict
# parent: evidence_genomics_england name: studyId
# parent: evidence_genomics_england name: studyOverview
# parent: evidence_genomics_england name: qualityControls
# dict
# parent: evidence_genomics_england name: diseaseId
# parent: evidence_genomics_england name: targetId
# parent: evidence_genomics_england name: publicationDate
# parent: evidence_genomics_england name: evidenceDate
# parent: evidence_genomics_england name: score
# parent: evidence_gwas_credible_sets name: id
# parent: evidence_gwas_credible_sets name: targetFromSourceId
# parent: evidence_gwas_credible_sets name: diseaseFromSourceMappedId
# parent: evidence_gwas_credible_sets name: datasourceId
# parent: evidence_gwas_credible_sets name: datatypeId
# parent: evidence_gwas_credible_sets name: literature
# dict
# parent: evidence_gwas_credible_sets name: resourceScore
# parent: evidence_gwas_credible_sets name: studyLocusId
# parent: evidence_gwas_credible_sets name: qualityControls
# dict
# parent: evidence_gwas_credible_sets name: diseaseId
# parent: evidence_gwas_credible_sets name: targetId
# parent: evidence_gwas_credible_sets name: publicationDate
# parent: evidence_gwas_credible_sets name: evidenceDate
# parent: evidence_gwas_credible_sets name: score
# parent: evidence_impc name: targetId
# parent: evidence_impc name: id
# parent: evidence_impc name: targetFromSourceId
# parent: evidence_impc name: diseaseFromSourceMappedId
# parent: evidence_impc name: biologicalModelAllelicComposition
# parent: evidence_impc name: biologicalModelGeneticBackground
# parent: evidence_impc name: biologicalModelId
# parent: evidence_impc name: datasourceId
# parent: evidence_impc name: datatypeId
# parent: evidence_impc name: diseaseFromSource
# parent: evidence_impc name: diseaseFromSourceId
# parent: evidence_impc name: diseaseModelAssociatedHumanPhenotypes
# dict
# array of struct
# parent: evidence_impc/diseaseModelAssociatedHumanPhenotypes name: id
# parent: evidence_impc/diseaseModelAssociatedHumanPhenotypes name: label
# parent: evidence_impc name: diseaseModelAssociatedModelPhenotypes
# dict
# array of struct
# parent: evidence_impc/diseaseModelAssociatedModelPhenotypes name: id
# parent: evidence_impc/diseaseModelAssociatedModelPhenotypes name: label
# parent: evidence_impc name: literature
# dict
# parent: evidence_impc name: resourceScore
# parent: evidence_impc name: targetInModel
# parent: evidence_impc name: targetInModelEnsemblId
# parent: evidence_impc name: targetInModelMgiId
# parent: evidence_impc name: qualityControls
# dict
# parent: evidence_impc name: diseaseId
# parent: evidence_impc name: publicationDate
# parent: evidence_impc name: evidenceDate
# parent: evidence_impc name: score
# parent: evidence_impc name: directionOnTrait
# parent: evidence_impc name: directionOnTarget
# parent: evidence_intogen name: targetId
# parent: evidence_intogen name: id
# parent: evidence_intogen name: targetFromSourceId
# parent: evidence_intogen name: diseaseFromSourceMappedId
# parent: evidence_intogen name: cohortDescription
# parent: evidence_intogen name: cohortId
# parent: evidence_intogen name: cohortShortName
# parent: evidence_intogen name: datasourceId
# parent: evidence_intogen name: datatypeId
# parent: evidence_intogen name: diseaseFromSource
# parent: evidence_intogen name: literature
# dict
# parent: evidence_intogen name: mutatedSamples
# dict
# array of struct
# parent: evidence_intogen/mutatedSamples name: functionalConsequenceId
# parent: evidence_intogen/mutatedSamples name: numberMutatedSamples
# parent: evidence_intogen/mutatedSamples name: numberSamplesTested
# parent: evidence_intogen name: resourceScore
# parent: evidence_intogen name: significantDriverMethods
# dict
# parent: evidence_intogen name: qualityControls
# dict
# parent: evidence_intogen name: diseaseId
# parent: evidence_intogen name: publicationDate
# parent: evidence_intogen name: evidenceDate
# parent: evidence_intogen name: score
# parent: evidence_intogen name: directionOnTrait
# parent: evidence_intogen name: directionOnTarget
# parent: evidence_orphanet name: targetId
# parent: evidence_orphanet name: id
# parent: evidence_orphanet name: targetFromSourceId
# parent: evidence_orphanet name: diseaseFromSourceMappedId
# parent: evidence_orphanet name: alleleOrigins
# dict
# parent: evidence_orphanet name: confidence
# parent: evidence_orphanet name: datasourceId
# parent: evidence_orphanet name: datatypeId
# parent: evidence_orphanet name: diseaseFromSource
# parent: evidence_orphanet name: diseaseFromSourceId
# parent: evidence_orphanet name: literature
# dict
# parent: evidence_orphanet name: targetFromSource
# parent: evidence_orphanet name: variantFunctionalConsequenceId
# parent: evidence_orphanet name: qualityControls
# dict
# parent: evidence_orphanet name: diseaseId
# parent: evidence_orphanet name: publicationDate
# parent: evidence_orphanet name: evidenceDate
# parent: evidence_orphanet name: score
# parent: evidence_orphanet name: directionOnTrait
# parent: evidence_orphanet name: directionOnTarget
# parent: evidence_ot_crispr name: targetFromSourceId
# parent: evidence_ot_crispr name: diseaseFromSourceMappedId
# parent: evidence_ot_crispr name: cellLineBackground
# parent: evidence_ot_crispr name: cellType
# parent: evidence_ot_crispr name: contrast
# parent: evidence_ot_crispr name: crisprScreenLibrary
# parent: evidence_ot_crispr name: datasourceId
# parent: evidence_ot_crispr name: datatypeId
# parent: evidence_ot_crispr name: log2FoldChangeValue
# parent: evidence_ot_crispr name: projectDescription
# parent: evidence_ot_crispr name: projectId
# parent: evidence_ot_crispr name: releaseDate
# parent: evidence_ot_crispr name: releaseVersion
# parent: evidence_ot_crispr name: resourceScore
# parent: evidence_ot_crispr name: statisticalTestTail
# parent: evidence_ot_crispr name: studyId
# parent: evidence_ot_crispr name: studyOverview
# parent: evidence_ot_crispr name: qualityControls
# dict
# parent: evidence_ot_crispr name: diseaseId
# parent: evidence_ot_crispr name: targetId
# parent: evidence_ot_crispr name: id
# parent: evidence_ot_crispr name: evidenceDate
# parent: evidence_ot_crispr name: score
# parent: evidence_ot_crispr_validation name: targetFromSourceId
# parent: evidence_ot_crispr_validation name: diseaseFromSourceMappedId
# parent: evidence_ot_crispr_validation name: assays
# dict
# array of struct
# parent: evidence_ot_crispr_validation/assays name: description
# parent: evidence_ot_crispr_validation/assays name: isHit
# parent: evidence_ot_crispr_validation/assays name: shortName
# parent: evidence_ot_crispr_validation name: assessments
# dict
# parent: evidence_ot_crispr_validation name: biomarkerList
# dict
# array of struct
# parent: evidence_ot_crispr_validation/biomarkerList name: description
# parent: evidence_ot_crispr_validation/biomarkerList name: name
# parent: evidence_ot_crispr_validation name: datasourceId
# parent: evidence_ot_crispr_validation name: datatypeId
# parent: evidence_ot_crispr_validation name: diseaseCellLines
# dict
# array of struct
# parent: evidence_ot_crispr_validation/diseaseCellLines name: id
# parent: evidence_ot_crispr_validation/diseaseCellLines name: name
# parent: evidence_ot_crispr_validation/diseaseCellLines name: tissue
# parent: evidence_ot_crispr_validation/diseaseCellLines name: tissueId
# parent: evidence_ot_crispr_validation name: diseaseFromSource
# parent: evidence_ot_crispr_validation name: primaryProjectHit
# parent: evidence_ot_crispr_validation name: primaryProjectId
# parent: evidence_ot_crispr_validation name: projectId
# parent: evidence_ot_crispr_validation name: releaseDate
# parent: evidence_ot_crispr_validation name: releaseVersion
# parent: evidence_ot_crispr_validation name: resourceScore
# parent: evidence_ot_crispr_validation name: studyOverview
# parent: evidence_ot_crispr_validation name: qualityControls
# dict
# parent: evidence_ot_crispr_validation name: diseaseId
# parent: evidence_ot_crispr_validation name: targetId
# parent: evidence_ot_crispr_validation name: id
# parent: evidence_ot_crispr_validation name: evidenceDate
# parent: evidence_ot_crispr_validation name: score
# parent: evidence_reactome name: id
# parent: evidence_reactome name: targetFromSourceId
# parent: evidence_reactome name: diseaseFromSourceMappedId
# parent: evidence_reactome name: datasourceId
# parent: evidence_reactome name: datatypeId
# parent: evidence_reactome name: diseaseFromSource
# parent: evidence_reactome name: diseaseFromSourceId
# parent: evidence_reactome name: literature
# dict
# parent: evidence_reactome name: pathways
# dict
# array of struct
# parent: evidence_reactome/pathways name: id
# parent: evidence_reactome/pathways name: name
# parent: evidence_reactome name: reactionId
# parent: evidence_reactome name: reactionName
# parent: evidence_reactome name: targetModulation
# parent: evidence_reactome name: variantAminoacidDescriptions
# dict
# parent: evidence_reactome name: qualityControls
# dict
# parent: evidence_reactome name: diseaseId
# parent: evidence_reactome name: targetId
# parent: evidence_reactome name: publicationDate
# parent: evidence_reactome name: evidenceDate
# parent: evidence_reactome name: score
# parent: evidence_uniprot_literature name: id
# parent: evidence_uniprot_literature name: targetFromSourceId
# parent: evidence_uniprot_literature name: diseaseFromSourceMappedId
# parent: evidence_uniprot_literature name: confidence
# parent: evidence_uniprot_literature name: datasourceId
# parent: evidence_uniprot_literature name: datatypeId
# parent: evidence_uniprot_literature name: diseaseFromSource
# parent: evidence_uniprot_literature name: diseaseFromSourceId
# parent: evidence_uniprot_literature name: literature
# dict
# parent: evidence_uniprot_literature name: targetModulation
# parent: evidence_uniprot_literature name: qualityControls
# dict
# parent: evidence_uniprot_literature name: diseaseId
# parent: evidence_uniprot_literature name: targetId
# parent: evidence_uniprot_literature name: publicationDate
# parent: evidence_uniprot_literature name: evidenceDate
# parent: evidence_uniprot_literature name: score
# parent: evidence_uniprot_variants name: id
# parent: evidence_uniprot_variants name: targetFromSourceId
# parent: evidence_uniprot_variants name: diseaseFromSourceMappedId
# parent: evidence_uniprot_variants name: confidence
# parent: evidence_uniprot_variants name: datasourceId
# parent: evidence_uniprot_variants name: datatypeId
# parent: evidence_uniprot_variants name: diseaseFromSource
# parent: evidence_uniprot_variants name: diseaseFromSourceId
# parent: evidence_uniprot_variants name: literature
# dict
# parent: evidence_uniprot_variants name: targetModulation
# parent: evidence_uniprot_variants name: variantId
# parent: evidence_uniprot_variants name: variantRsId
# parent: evidence_uniprot_variants name: qualityControls
# dict
# parent: evidence_uniprot_variants name: diseaseId
# parent: evidence_uniprot_variants name: targetId
# parent: evidence_uniprot_variants name: publicationDate
# parent: evidence_uniprot_variants name: evidenceDate
# parent: evidence_uniprot_variants name: score

# %%
old_evidence = get_full_evidence(gid)
old_evidence.head()
# Out:
#                    column_description foreign_key bioregistry_prefix  \
# 202  Identifer of the evidence source         NaN                NaN
# 203    Open Targets target identifier   target/id                NaN
# 204      Origin of the variant allele         NaN                NaN
# 205              Inheritance patterns         NaN                NaN
# 206    Genetic origin of a population         NaN                NaN
#
#               field_join
# 202         datasourceId
# 203             targetId
# 204        alleleOrigins
# 205  allelicRequirements
# 206             ancestry

# %%
updated_evidence_table = (
    new_evidence_collated
    .merge(
        old_evidence, on='field_join', how='left'
    )
    # Updating missing descriptions:
    .assign(
        column_description = lambda df: df.apply(
            lambda row: 
              "Evidence quality flags" if row['column_name'] == 'qualityControls' else 
              "Effect of direction on target" if row['column_name'] == 'directionOnTarget' else
              row['column_description'],
            axis=1
        )
    )
)


updated_evidence_table.loc[lambda df: df.column_description.isna()]
# Out:
# Empty DataFrame
# Columns: [dataset_name, field_id, column_name, field_join, column_description, foreign_key, bioregistry_prefix]
# Index: []

# %%
(
    pd.concat([
        updated_evidence_table,
        get_full_croissant(gid).loc[lambda df: df.dataset_name != 'evidence']
    ])
    .drop(['Example', 'field_join'], axis=1)
    .sort_values(['dataset_name', 'field_id'])
    .to_csv('annotated_new_evidence_columns.csv', index=False, sep=',')
)

# %%
len(pd.read_csv('annotated_new_evidence_columns.csv'))
# Out:
# 1199

# %%
(
    updated_evidence_table
    .assign(
        column_description = lambda df: df.apply(
            lambda row: 
              "Evidence quality flags" if row['column_name'] == 'qualityControls' else 
              "Effect of direction on target" if row['column_name'] == 'directionOnTarget' else
              row['column_description'],
            axis=1
        )
    )
    .loc[updated_evidence_table.column_description.isna()]
)
# Out:
#                       dataset_name  \
# 23      evidence_cancer_biomarkers
# 44     evidence_cancer_gene_census
# 50     evidence_cancer_gene_census
# 69                 evidence_chembl
# 75                 evidence_chembl
# 88                evidence_clingen
# 108                evidence_crispr
# 131         evidence_crispr_screen
# 164                evidence_encore
# 186             evidence_europepmc
# 213                   evidence_eva
# 219                   evidence_eva
# 241           evidence_eva_somatic
# 247           evidence_eva_somatic
# 262      evidence_expression_atlas
# 301           evidence_gene_burden
# 307           evidence_gene_burden
# 321        evidence_gene2phenotype
# 327        evidence_gene2phenotype
# 341      evidence_genomics_england
# 355    evidence_gwas_credible_sets
# 383                  evidence_impc
# 389                  evidence_impc
# 407               evidence_intogen
# 413               evidence_intogen
# 427              evidence_orphanet
# 433              evidence_orphanet
# 451             evidence_ot_crispr
# 482  evidence_ot_crispr_validation
# 503              evidence_reactome
# 519    evidence_uniprot_literature
# 537      evidence_uniprot_variants
#
#                                           field_id        column_name  \
# 23      evidence_cancer_biomarkers/qualityControls    qualityControls
# 44     evidence_cancer_gene_census/qualityControls    qualityControls
# 50   evidence_cancer_gene_census/directionOnTarget  directionOnTarget
# 69                 evidence_chembl/qualityControls    qualityControls
# 75               evidence_chembl/directionOnTarget  directionOnTarget
# 88                evidence_clingen/qualityControls    qualityControls
# 108                evidence_crispr/qualityControls    qualityControls
# 131         evidence_crispr_screen/qualityControls    qualityControls
# 164                evidence_encore/qualityControls    qualityControls
# 186             evidence_europepmc/qualityControls    qualityControls
# 213                   evidence_eva/qualityControls    qualityControls
# 219                 evidence_eva/directionOnTarget  directionOnTarget
# 241           evidence_eva_somatic/qualityControls    qualityControls
# 247         evidence_eva_somatic/directionOnTarget  directionOnTarget
# 262      evidence_expression_atlas/qualityControls    qualityControls
# 301           evidence_gene_burden/qualityControls    qualityControls
# 307         evidence_gene_burden/directionOnTarget  directionOnTarget
# 321        evidence_gene2phenotype/qualityControls    qualityControls
# 327      evidence_gene2phenotype/directionOnTarget  directionOnTarget
# 341      evidence_genomics_england/qualityControls    qualityControls
# 355    evidence_gwas_credible_sets/qualityControls    qualityControls
# 383                  evidence_impc/qualityControls    qualityControls
# 389                evidence_impc/directionOnTarget  directionOnTarget
# 407               evidence_intogen/qualityControls    qualityControls
# 413             evidence_intogen/directionOnTarget  directionOnTarget
# 427              evidence_orphanet/qualityControls    qualityControls
# 433            evidence_orphanet/directionOnTarget  directionOnTarget
# 451             evidence_ot_crispr/qualityControls    qualityControls
# 482  evidence_ot_crispr_validation/qualityControls    qualityControls
# 503              evidence_reactome/qualityControls    qualityControls
# 519    evidence_uniprot_literature/qualityControls    qualityControls
# 537      evidence_uniprot_variants/qualityControls    qualityControls
#
#             field_join             column_description foreign_key  \
# 23     qualityControls         Evidence quality flags         NaN
# 44     qualityControls         Evidence quality flags         NaN
# 50   directionOnTarget  Effect of direction on target         NaN
# 69     qualityControls         Evidence quality flags         NaN
# 75   directionOnTarget  Effect of direction on target         NaN
# 88     qualityControls         Evidence quality flags         NaN
# 108    qualityControls         Evidence quality flags         NaN
# 131    qualityControls         Evidence quality flags         NaN
# 164    qualityControls         Evidence quality flags         NaN
# 186    qualityControls         Evidence quality flags         NaN
# 213    qualityControls         Evidence quality flags         NaN
# 219  directionOnTarget  Effect of direction on target         NaN
# 241    qualityControls         Evidence quality flags         NaN
# 247  directionOnTarget  Effect of direction on target         NaN
# 262    qualityControls         Evidence quality flags         NaN
# 301    qualityControls         Evidence quality flags         NaN
# 307  directionOnTarget  Effect of direction on target         NaN
# 321    qualityControls         Evidence quality flags         NaN
# 327  directionOnTarget  Effect of direction on target         NaN
# 341    qualityControls         Evidence quality flags         NaN
# 355    qualityControls         Evidence quality flags         NaN
# 383    qualityControls         Evidence quality flags         NaN
# 389  directionOnTarget  Effect of direction on target         NaN
# 407    qualityControls         Evidence quality flags         NaN
# 413  directionOnTarget  Effect of direction on target         NaN
# 427    qualityControls         Evidence quality flags         NaN
# 433  directionOnTarget  Effect of direction on target         NaN
# 451    qualityControls         Evidence quality flags         NaN
# 482    qualityControls         Evidence quality flags         NaN
# 503    qualityControls         Evidence quality flags         NaN
# 519    qualityControls         Evidence quality flags         NaN
# 537    qualityControls         Evidence quality flags         NaN
#
#     bioregistry_prefix
# 23                 NaN
# 44                 NaN
# 50                 NaN
# 69                 NaN
# 75                 NaN
# 88                 NaN
# 108                NaN
# 131                NaN
# 164                NaN
# 186                NaN
# 213                NaN
# 219                NaN
# 241                NaN
# 247                NaN
# 262                NaN
# 301                NaN
# 307                NaN
# 321                NaN
# 327                NaN
# 341                NaN
# 355                NaN
# 383                NaN
# 389                NaN
# 407                NaN
# 413                NaN
# 427                NaN
# 433                NaN
# 451                NaN
# 482                NaN
# 503                NaN
# 519                NaN
# 537                NaN
